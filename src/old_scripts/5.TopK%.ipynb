# %%
import pandas as pd
import ast
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
import ast
import csv
import seaborn as sns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
path = "/content/neuron_contribution_between_class.csv"
df = pd.read_csv(path)
df.head()
# Out:
#    Unnamed: 0 type  layer class1       class2  Neuron_ID  Contribution
# 0           0  mlp      7   math  programming       6117  8.144039e+11
# 1           1  mlp     24   math  programming       9329  7.782393e+11
# 2           2  mlp     23   math  programming      10184  7.565522e+11
# 3           3  res      1   math  programming      12054  6.470184e+11
# 4           4  mlp     24   math  programming        282  5.486137e+11

# %%
topK = [10, 20, 30, 40, 50, 60, 70, 80, 90]

# %%
df.shape
# Out:
# (2354851, 7)

# %%
p = 1.0

# 3. compute the integer index for that percentile
#    note: len(sorted_contrib)-1 so that p=1.0 lands on the last element
idx = int(p * (df.shape[0] - 1))

print(idx)
# 4. pull out the value
value_at_p = df.iloc[idx]

print(f"{p*100:.1f}% of the way through the sorted contributions → index {idx} → contribution = {value_at_p}")
# Out:
# 2354850
# 100.0% of the way through the sorted contributions → index 2354850 → contribution = Unnamed: 0          2354850
# type                    res
# layer                     2
# class1                 math
# class2          programming
# Neuron_ID             15056
# Contribution            1.0
# Name: 2354850, dtype: object
