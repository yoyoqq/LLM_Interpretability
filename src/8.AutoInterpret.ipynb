# %%
import pandas as pd
classes = ["empathetic_dialogue", "math", "mmlu", "programming"]
path = f"./datasets/dot_product/{classes[0]}_between_class_clean_topk.csv"
# path = "./datasets/dot_product/negative_feelings.csv"
df = pd.read_csv(path, encoding="utf-8-sig")
df.head(20)
# Out:
#    type  layer        class1    class2  Neuron_ID  Contribution  \
# 0   mlp     24  apprehensive  trusting        282    15015042.0
# 1   att     22  apprehensive  trusting      14953    13710207.0
# 2   mlp     24  apprehensive  trusting       9329    12911080.0
# 3   att     12  apprehensive  trusting       2424    12815097.0
# 4   att      7  apprehensive  trusting      10364    11636983.0
# 5   res      1  apprehensive  trusting      12054    11112904.0
# 6   mlp      7  apprehensive  trusting       6117    10844195.0
# 7   att      5  apprehensive  trusting       9670    10387046.0
# 8   att     23  apprehensive  trusting       5279    10378344.0
# 9   res     12  apprehensive  trusting       2620     9890904.0
# 10  mlp     25  apprehensive  trusting      13264     9418176.0
# 11  att     11  apprehensive  trusting      11572     9055968.0
# 12  att     10  apprehensive  trusting       3101     8977803.0
# 13  att     17  apprehensive  trusting      12484     8890720.0
# 14  att     10  apprehensive  trusting       7009     8765370.0
# 15  att     17  apprehensive    lonely      14463     8655339.0
# 16  mlp      4  apprehensive  trusting      14164     8180843.0
# 17  res     13   embarrassed  trusting      11256     7955541.0
# 18  mlp      4  apprehensive  trusting       2793     7938540.0
# 19  att      9  apprehensive  trusting       4597     7921170.0
#
#                                           Explanation
# 0                        hyperlinks and web addresses
# 1    attends to specific significant tokens from s...
# 2    legal terms and phrases related to court case...
# 3    attends from tokens denoting an action or con...
# 4    attends to instances of the token followed by...
# 5   content related to medical conditions and trea...
# 6    topics related to nutrition and health measur...
# 7    attends to specific tokens lacking any conten...
# 8    attends to the token "by" from the surroundin...
# 9   words associated with authority, control, and ...
# 10            elements related to conflict and action
# 11   attends to regulatory or function-determining...
# 12   attends to the token "ern" from the adjacent ...
# 13   attends to alphanumeric tokens from the secon...
# 14   attends to terms related to a specific token ...
# 15   attends to tokens like "kg" and "kJ" from oth...
# 16  structured programming elements and documentat...
# 17  phrases related to product features and specif...
# 18  terms related to legal and regulatory document...
# 19   attends to terminal punctuation marks from br...

# %%
import requests

def get_feature(model_id, source, index):
    try:
        url = f"https://www.neuronpedia.org/api/feature/{model_id}/{source}/{index}"
        resp = requests.get(url)
        resp.raise_for_status()            # throws if not 200
        feature = resp.json()

        # 2. Grab the list of explanations (might be empty!)
        explanations = feature.get("explanations", [])

        # 3. first description:
        # if explanations:
        return explanations[0]["description"]
    except Exception as e:
        return None

# %%
from tqdm.auto import tqdm

model = "gemma-2-2b"
explanations = []
if "Explanation" not in df.columns:
    df["Explanation"] = None

to_process = 50000

# %%
# for idx, row in df.head(24700).iterrows():
# for idx, row in tqdm(df.iterrows(), total=len(df), desc="Fetching features"):
for idx, row in tqdm(df.head(25000).iterrows(), total=min(25000, len(df)), desc="Fetching features"):
    sae_type  = row["type"]
    layer     = row["layer"]
    neuron_id = row["Neuron_ID"]
    source    = f"{layer}-gemmascope-{sae_type}-16k"
    if pd.notna(row["Explanation"]):
        continue
    feat = get_feature(model, source, neuron_id)
    df.at[idx, "Explanation"] = feat

# df["Explanation"] = explanations
df.to_csv(path, index=False, encoding="utf-8-sig")
# Out:
# Fetching features:   0%|          | 0/25000 [00:00<?, ?it/s]

# %%
import pandas as pd
from tqdm.auto import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed

model = "gemma-2-2b"

def parallel_fetch_feature(args):
    try:
      """Helper function for parallel processing"""
      idx, row = args
      sae_type = row["type"]
      layer = row["layer"]
      neuron_id = row["Neuron_ID"]
      source = f"{layer}-gemmascope-{sae_type}-16k"

      feat = get_feature(model, source, neuron_id)
      return idx, feat
    except Exception as e:
      print(e)
      return None, None

def parallel_approach(df, path, max_workers=8):
    """Use parallel processing with skipping for existing explanations"""
    if "Explanation" not in df.columns:
        df["Explanation"] = None

    df_subset = df.head(to_process)

    # SKIP ROWS THAT ALREADY HAVE EXPLANATIONS
    # Filter out rows where Explanation is not None/NaN/empty
    rows_to_process = []
    skipped_count = 0

    for idx, row in df_subset.iterrows():
        # Skip if explanation already exists and is not None/NaN/empty
        if pd.notna(row.get("Explanation")) and row.get("Explanation") not in ["", None]:
            skipped_count += 1
            continue
        rows_to_process.append((idx, row))

    print(f"Skipping {skipped_count} rows that already have explanations")
    print(f"Processing {len(rows_to_process)} rows out of {len(df_subset)} total")

    if not rows_to_process:
        print("All rows already have explanations!")
        df.to_csv(path, index=False, encoding="utf-8-sig")
        return

    # THE PARALLEL PROCESSING HAPPENS HERE:
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Submit only the rows that need processing
        future_to_idx = {executor.submit(parallel_fetch_feature, args): args[0]
                        for args in rows_to_process}

        # Process completed tasks with progress bar
        for future in tqdm(as_completed(future_to_idx), total=len(rows_to_process), desc="Fetching features"):
            idx = future_to_idx[future]
            try:
                result_idx, feat = future.result()
                df.at[result_idx, "Explanation"] = feat
            except Exception as exc:
                print(f'Row {idx} generated an exception: {exc}')
                continue

    df.to_csv(path, index=False, encoding="utf-8-sig")

parallel_approach(df, path, max_workers=8)  # Recommended for I/O bound operations
# Out:
# Skipping 24999 rows that already have explanations
# Processing 25001 rows out of 50000 total
# Fetching features:   0%|          | 0/25001 [00:00<?, ?it/s]

# %%
df.to_csv(path, index=False, encoding="utf-8-sig")

# %%
# select the first 25 000 rows
subset = df.iloc[0:to_process]

# count None/NaN values in the ‘Explanation’ column
none_count = subset['Explanation'].isna().sum()

print(f"Number of missing explanations in rows 0–24999: {none_count}")
# Out:
# Number of missing explanations in rows 0–24999: 3

# %%
# take rows 0–24999
subset = df.iloc[0:to_process]

# select only those with missing Explanation
missing = subset[subset["Explanation"].isna()]

# show them
print(missing)
# Out:
#       type  layer        class1       class2  Neuron_ID  Contribution  \
# 3971   att     24  apprehensive      excited       9145        2891.0
# 4122   att     24    devastated    disgusted       9099        2754.0
# 49999  mlp     12    devastated  sentimental       6384          63.0
#
#       Explanation
# 3971         None
# 4122         None
# 49999        None

# %%
df['layer'] = df['layer'].astype('Int64')
df['Neuron_ID'] = df['Neuron_ID'].astype('Int64')

# %% [markdown]
# # Within class

# %%
import pandas as pd

# %%
DEPLOYMENT_NAME = 0


DATASET_NAMES = [
    "programming",
    "mmlu",
    "math",
    "empethetic_dialogue"
]
# DATASET_NAMES = [
#     "negative_feelings",
#     "law_and_policy",
#     "positive_feelings",
#     "philosophy_and_ethics"
# ]

PATH = f"./datasets/dot_product/{DATASET_NAMES[DEPLOYMENT_NAME]}_between_class_clean.csv"
# PATH = f"./datasets/dot_product/{}.csv"
print(PATH)
# Out:
# ./datasets/dot_product/programming_between_class_clean.csv

# %%
df = pd.read_csv(PATH, dtype={ "layer": int, "Neuron_ID": int })
df.head()
# Out:
#   type  layer    class1      class2  Neuron_ID  Contribution
# 0  mlp      7  external  codeforces       6117  6.946736e+11
# 1  mlp     23  external  codeforces      10184  6.392421e+11
# 2  mlp     24  external  codeforces       9329  6.118761e+11
# 3  res      1  external  codeforces      12054  5.498718e+11
# 4  mlp      4  external  codeforces       2793  4.683499e+11

# %%
df.columns
# Out:
# Index(['type', 'layer', 'class1', 'class2', 'Neuron_ID', 'Contribution',
#        'Explanation'],
#       dtype='object')

# %%
import sqlite3
import pandas as pd

# 0) assume DATASET_NAMES is defined, and your DB has columns typ, layer, neuron_index
# 1) Open the DB connection
conn = sqlite3.connect("./datasets/explanations.db")
cur  = conn.cursor()

for dataset_name in DATASET_NAMES:
    src_path = f"./datasets/dot_product/{DATASET_NAMES[DEPLOYMENT_NAME]}_between_class_clean.csv"
    out_path = f"./datasets/dot_product/{dataset_name}_with_explanations.csv"

    # read with the right dtypes
    df = pd.read_csv(src_path, dtype={ "layer": int, "Neuron_ID": int })

    descriptions = []

    # 2) Loop over your DataFrame rows
    for idx, row in df.iterrows():
        typ       = row["type"]
        layer     = row["layer"]
        neuron_id = row["Neuron_ID"]

        # 3) Query using your variables
        cur.execute(
            """
            SELECT description
              FROM explanations
             WHERE typ = ?
               AND layer = ?
               AND neuron_index = ?
            """,
            (typ, layer, neuron_id)
        )

        result = cur.fetchone()
        descriptions.append(result[0] if result else None)

    # 4) Assign back into your DataFrame
    df["Explanations"] = descriptions

    # 5) Write out (no index column)
    df.to_csv(out_path, index=False)
    print(f"Wrote {out_path}")

# 6) Clean up
cur.close()
conn.close()
# Out:
# /tmp/ipykernel_545581/2414650808.py:14: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(src_path, dtype={ "layer": int, "Neuron_ID": int })
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 36
#      24     # 3) Query using your variables
#      25     cur.execute(
#      26         """
#      27         SELECT description
#    (...)     33         (typ, layer, neuron_id)
#      34     )
# ---> 36     result = cur.fetchone()
#      37     descriptions.append(result[0] if result else None)
#      39 # 4) Assign back into your DataFrame
#
# KeyboardInterrupt:

# %%
from tqdm import tqdm
import sqlite3
import pandas as pd

conn = sqlite3.connect("./datasets/explanations.db")

# load once
expl_df = pd.read_sql_query(
    "SELECT typ, layer, neuron_index, description FROM explanations",
    conn,
    dtype={"typ": str, "layer": int, "neuron_index": int},
)

for dataset_name in tqdm(DATASET_NAMES, desc="Datasets"):
    df = pd.read_csv(f"./datasets/dot_product/{DATASET_NAMES[DEPLOYMENT_NAME]}_between_class_clean.csv",
                     dtype={"type": str, "layer": int, "Neuron_ID": int})

    merged = (
        df
        .merge(
            expl_df,
            left_on=["type", "layer", "Neuron_ID"],
            right_on=["typ", "layer", "neuron_index"],
            how="left",
        )
        .drop(columns=["typ", "neuron_index"])
        .rename(columns={"description": "Explanations"})
    )

    merged.to_csv(f"./datasets/dot_product/{dataset_name}_with_explanations.csv",
                  index=False)

conn.close()
# Out:
# Datasets: 100%|██████████| 4/4 [00:09<00:00,  2.40s/it]

# %% [markdown]
# # Auto interpret between class

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('./datasets/explanations.csv')

# Create the dictionary mapping (typ, layer, neuron_index) -> description
mapping = df.set_index(['typ', 'layer', 'neuron_index'])['description'].to_dict()

# Display the resulting dictionary
mapping
# Out:
# {('res',
#   0,
#   11837): 'references to a specific individual or entity denoted by "Del."',
#  ('res', 0, 11838): 'expressions of concern or indifference from the speaker',
#  ('res', 0, 11839): ' instances of the word "notice" in various contexts',
#  ('res',
#   0,
#   1184): 'references to specific technical or programming terms and their associated components',
#  ('res', 0, 11840): ' patterns related to database row processing',
#  ('res', 0, 11841): 'references to poetry and poetic forms',
#  ('res',
#   0,
#   11842): 'terms and concepts related to statistics, analysis, and programming for technical applications',
#  ('res',
#   0,
#   11843): 'phrases associated with achieving goals or reaching targets',
#  ('res',
#   0,
#   11844): 'instances of the word "touch" in various forms and contexts',
#  ('res', 0, 11845): 'references to environmental factors and measurements',
#  ('res',
#   0,
#   11846): 'terms related to legal concepts, specifically judicial canons and their implications',
#  ('res', 0, 11847): ' references to bulk materials',
#  ('res',
#   0,
#   11848): 'references to high-ranking or top-rated entities or positions',
#  ('res',
#   0,
#   11849): 'technical terms and keywords related to programming and data classes',
#  ('res', 0, 1185): 'mathematical operations and numerical comparisons',
#  ('res', 0, 11850): 'references to matrices and matrix-related concepts',
#  ('res',
#   0,
#   11851): ' instances of the word "teach" and its variations related to educational context',
#  ('res',
#   0,
#   11852): 'the name Kim, indicating a focus on identifying this specific individual in the text',
#  ('res',
#   0,
#   11853): 'terms related to data packet headers and header processing in network communications',
#  ('res',
#   0,
#   11854): 'terms related to mathematical and statistical functions, particularly regarding regression testing and gene analysis',
#  ('res', 0, 11855): 'words related to screen capturing functionality',
#  ('res', 0, 11856): 'references to "swing" and "chemical" related concepts',
#  ('res', 0, 11857): 'references to a specific gene or genetic changes',
#  ('res', 0, 11858): 'references to games and game components',
#  ('res', 0, 11859): 'references to automobiles or vehicles',
#  ('res',
#   0,
#   1186): 'words or terms related to a specific scientific or academic discipline',
#  ('res',
#   0,
#   11860): 'the mention of specific names or references related to Malaysian politics',
#  ('res',
#   0,
#   11861): 'references to abundance or prominence expressed through arrows',
#  ('res',
#   0,
#   11862): 'sections or keywords related to methodologies and statistical analysis',
#  ('res', 0, 11863): ' terms related to spatial concepts or dimensions',
#  ('res',
#   0,
#   11864): 'instances of legal terms and references to statements in a regulatory context',
#  ('res', 0, 11865): 'words related to ongoing actions or processes',
#  ('res',
#   0,
#   11866): 'references to emperors and the concept of transmission in the context of power dynamics or communications',
#  ('res', 0, 11867): 'the term "usual" and its variations or contexts',
#  ('res', 0, 11868): 'the term "ser" in various contexts',
#  ('res', 0, 11869): 'references to honorific titles or formal acknowledgments',
#  ('res',
#   0,
#   1187): " references to travel or activities taking place outside one's home country",
#  ('res',
#   0,
#   11870): " mentions or references to something being 'pending' or awaiting action",
#  ('res', 0, 11871): 'references to violence and acts of aggression',
#  ('res', 0, 11872): 'phrases indicating recent events or occurrences',
#  ('res', 0, 11873): 'terms associated with measurement or quantification',
#  ('res',
#   0,
#   11874): 'technical terms related to testing and performance metrics in programming',
#  ('res',
#   0,
#   11875): 'instances of the word "stupid" and related negative descriptors',
#  ('res', 0, 11876): 'references to the concept of nature',
#  ('res', 0, 11877): 'expressions of disappointment in various contexts',
#  ('res', 0, 11878): 'references to LED technology and lighting systems',
#  ('res',
#   0,
#   11879): ' references to driving or related concepts in various contexts',
#  ('res',
#   0,
#   1188): 'words related to the medical field, specifically anti-epileptic drugs and their characteristics',
#  ('res', 0, 11880): 'references to specific experimental drugs or treatments',
#  ('res',
#   0,
#   11881): ' phrases indicating direction, progression, or change, particularly involving movement backward or forward',
#  ('res', 0, 11882): ' references to legal rulings or judgments',
#  ('res',
#   0,
#   11883): ' occurrences of the word "bye" and various related terms in different contexts',
#  ('res', 0, 11884): 'financial metrics related to interest rates',
#  ('res',
#   0,
#   11885): ' components related to web application programming and data processing errors',
#  ('res', 0, 11886): 'references to limitations or restrictions',
#  ('res', 0, 11887): ' phrases indicating actions and their consequences',
#  ('res', 0, 11888): 'instances of the word "archive" and its variations',
#  ('res',
#   0,
#   11889): ' references to the concept of absolute values in mathematical or technical contexts',
#  ('res',
#   0,
#   1189): 'keywords and identifiers related to programming and specific functions in code',
#  ('res', 0, 11890): 'mentions of lamps and related terminology',
#  ('res',
#   0,
#   11891): 'the word "absolutely" and its emphasis in various contexts',
#  ('res',
#   0,
#   11892): ' references to sports events, specifically focusing on the "Cup"',
#  ('res', 0, 11893): 'references to corruption and related offenses',
#  ('res', 0, 11894): 'words related to exporting data or content',
#  ('res',
#   0,
#   11895): 'references to specific age groups, particularly focusing on young individuals and the elderly',
#  ('res',
#   0,
#   11896): 'repeated instances or patterns of specific character strings, particularly focusing on "ich"',
#  ('res',
#   0,
#   11897): ' mathematical expressions involving fractions and derivatives',
#  ('res', 0, 11898): 'references to braking systems and components',
#  ('res', 0, 11899): ' references to figures in a document',
#  ('res',
#   0,
#   119): 'specific scientific terms and references related to biochemistry and pharmacology',
#  ('res',
#   0,
#   1190): 'the term "Sw," likely indicating a focus on a specific virus or related research',
#  ('res', 0, 11900): 'repeated instances of the term "Pet."',
#  ('res', 0, 11901): ' references to IP addresses',
#  ('res', 0, 11902): 'references to the concept of complementarity',
#  ('res',
#   0,
#   11903): 'mathematical functions and their variances in statistical contexts',
#  ('res', 0, 11904): 'references to the summer season',
#  ('res', 0, 11905): 'terms related to biology and bioengineering',
#  ('res', 0, 11906): ' occurrences of the abbreviation "CC"',
#  ('res', 0, 11907): 'references to parameters in technical documents',
#  ('res', 0, 11908): 'terms related to severity of conditions or events',
#  ('res', 0, 11909): 'mentions of the name "Cameron."',
#  ('res', 0, 1191): ' the presence of seeds in various contexts',
#  ('res', 0, 11910): ' references to remote operations or remote locations',
#  ('res',
#   0,
#   11911): ' terms and phrases related to data analysis and testing in programming contexts',
#  ('res',
#   0,
#   11912): 'technical programming terminology and references to database management',
#  ('res', 0, 11913): 'references to symbols and their meanings',
#  ('res',
#   0,
#   11914): 'references to measurements and configurations related to shapes or structures in programming contexts',
#  ('res', 0, 11915): 'references to dietary patterns and behaviors',
#  ('res',
#   0,
#   11916): ' technical terms and data structures related to programming and serialization',
#  ('res',
#   0,
#   11917): 'modal verbs and auxiliary verbs indicating possibility or obligation',
#  ('res', 0, 11918): 'instances of the word "trace"',
#  ('res', 0, 11919): ' references to tin or discussions surrounding tin',
#  ('res', 0, 1192): 'instances of the word "mere" and its variants',
#  ('res',
#   0,
#   11920): 'references to relationships or connections between concepts',
#  ('res', 0, 11921): 'HTML tags and elements in the text',
#  ('res', 0, 11922): ' XML or HTML tags and structure within the document',
#  ('res', 0, 11923): 'references to the concept of defeat',
#  ('res',
#   0,
#   11924): 'terms and concepts related to assembly versions and file properties in programming',
#  ('res',
#   0,
#   11925): ' references to classical concepts or systems, particularly in scientific contexts',
#  ('res',
#   0,
#   11926): ' occurrences of the word "final" and related terms suggesting completion or end',
#  ('res',
#   0,
#   11927): ' references to timers and related functions in programming contexts',
#  ('res', 0, 11928): 'references to witches and related themes',
#  ('res', 0, 11929): 'references to the act of wrapping or encasing something',
#  ('res', 0, 1193): 'function definitions and object instantiations',
#  ('res', 0, 11930): ' occurrences of the word "the"',
#  ('res', 0, 11931): 'terms related to tree data structures',
#  ('res', 0, 11932): 'references to tags or labeling categories',
#  ('res', 0, 11933): ' percentages and mathematical notations',
#  ('res',
#   0,
#   11934): 'HTML elements related to form inputs and user interface components',
#  ('res', 0, 11935): 'instances of the name "Kim."',
#  ('res',
#   0,
#   11936): ' technical terms related to programming, particularly for data handling and system errors',
#  ('res', 0, 11937): 'references to polling or survey data',
#  ('res', 0, 11938): 'terms related to medical stages and assessments',
#  ('res',
#   0,
#   11939): 'attributes and properties related to HTML or web development context',
#  ('res', 0, 1194): ' references to illness or health-related conditions',
#  ('res', 0, 11940): 'references to infection and infectious diseases',
#  ('res',
#   0,
#   11941): 'the adjective "merely" and its variations, indicating minimalism or simplicity in context',
#  ('res', 0, 11942): 'legal terms and citations',
#  ('res', 0, 11943): 'references to trends in various contexts',
#  ('res',
#   0,
#   11944): ' verbs indicating processes or actions related to creation, presentation, and manipulation',
#  ('res',
#   0,
#   11945): 'references to the surname "Taylor" and terms related to characteristics or properties in a technical context',
#  ('res', 0, 11946): 'references to the letter "O" in various contexts',
#  ('res',
#   0,
#   11947): 'technical terms related to medical and biological conditions',
#  ('res',
#   0,
#   11948): 'references to events or occurrences that are described as having happened',
#  ('res',
#   0,
#   11949): 'references to items or concepts identified as widespread or frequently occurring',
#  ('res', 0, 1195): ' mentions of design and related concepts',
#  ('res', 0, 11950): 'terms related to inflammation and its effects',
#  ('res', 0, 11951): ' legal terminologies related to injury and liability',
#  ('res', 0, 11952): 'references to strictness or stringent rules',
#  ('res',
#   0,
#   11953): 'references to monthly payment schedules or financial terms',
#  ('res',
#   0,
#   11954): ' references to specific mathematical concepts or operations involving trigonometric functions and stretching',
#  ('res', 0, 11955): 'references to magnetic properties',
#  ('res',
#   0,
#   11956): 'references to high-definition (HD) quality formats or standards',
#  ('res',
#   0,
#   11957): 'references to various systems in a technical or scientific context',
#  ('res',
#   0,
#   11958): "references to the concept of 'Western' or issues related to Western cultures and societies",
#  ('res',
#   0,
#   11959): ' references to the concept of application in various contexts',
#  ('res',
#   0,
#   1196): ' punctuations and parentheses used in formatting or referencing',
#  ('res', 0, 11960): 'references to commercial products and applications',
#  ('res', 0, 11961): 'instances of the word "random" and its variations',
#  ('res',
#   0,
#   11962): 'terms related to financial transactions and their attributes',
#  ('res', 0, 11963): 'references to departments within organizational contexts',
#  ('res', 0, 11964): ' terms related to legal judgments and court decisions',
#  ('res',
#   0,
#   11965): 'data related to mathematical operations, specifically functions and variables',
#  ('res',
#   0,
#   11966): "present tense gerunds, specifically verbs ending in 'ling'",
#  ('res', 0, 11967): 'instances of the word "recommend" and variations of it',
#  ('res',
#   0,
#   11968): "words related to size, specifically emphasizing the concept of 'small' and its variations",
#  ('res',
#   0,
#   11969): 'mathematical or scientific terminology related to equations and transformations',
#  ('res', 0, 1197): 'references to cats',
#  ('res',
#   0,
#   11970): 'references to people, particularly their roles and positions',
#  ('res',
#   0,
#   11971): ' technical terms and annotations related to programming and API specifications',
#  ('res', 0, 11972): 'terms related to resource distribution and allocation',
#  ('res', 0, 11973): ' references to geographical or defined areas',
#  ('res', 0, 11974): ' mentions of "school" or related educational terms',
#  ('res',
#   0,
#   11975): ' references to the C++ programming language and its associated features',
#  ('res',
#   0,
#   11976): ' references to interactive elements or features in the text',
#  ('res',
#   0,
#   11977): 'references to conditions and their implications in various contexts',
#  ('res',
#   0,
#   11978): 'words that discuss the effects or consequences of actions or events',
#  ('res', 0, 11979): ' references to folk traditions or cultural practices',
#  ('res',
#   0,
#   1198): 'expressions of surprise or reactions to unexpected situations',
#  ('res',
#   0,
#   11980): 'terms related to the concept of reversing and lubrication processes',
#  ('res', 0, 11981): ' references to customer data and validation processes',
#  ('res', 0, 11982): 'various HTML input elements and their attributes',
#  ('res', 0, 11983): ' references to tent structures and atomic elements',
#  ('res', 0, 11984): 'references to study or identity-related terms',
#  ('res', 0, 11985): 'references to weight in pounds',
#  ('res',
#   0,
#   11986): ' terms related to academic classification or status, particularly focusing on "freshman."',
#  ('res', 0, 11987): 'references to strength or intensity in various contexts',
#  ('res', 0, 11988): " instances of the word 'standing' and its variations",
#  ('res', 0, 11989): ' instances of the term "keyword" and related terms',
#  ('res',
#   0,
#   1199): 'phrases related to the intensity of interventions or actions',
#  ('res', 0, 11990): 'conjunctions, particularly the word "and"',
#  ('res', 0, 11991): 'terms related to washing and rinsing processes',
#  ('res',
#   0,
#   11992): 'terms related to medical conditions and frequency references',
#  ('res', 0, 11993): 'references to periodic payment schedules',
#  ('res',
#   0,
#   11994): 'patterns related to structural elements and code formatting',
#  ('res',
#   0,
#   11995): ' occurrences of a specific character or entity within narrative contexts',
#  ('res',
#   0,
#   11996): 'references to data processing steps, specifically "pipeline" within various contexts',
#  ('res', 0, 11997): 'instances of the word "correctly"',
#  ('res',
#   0,
#   11998): 'punctuation marks and close parentheses in mathematical expressions',
#  ('res',
#   0,
#   11999): 'references to quantities, specifically large numbers or counts',
#  ('res', 0, 12): ' mentions of trade and trading-related terms',
#  ('res',
#   0,
#   120): 'expressions involving the verb "be" in various forms and contexts',
#  ('res',
#   0,
#   1200): 'specific coding patterns or constructs related to safe memory management and instance state handling',
#  ('res',
#   0,
#   12000): 'general references to various types of content or activities',
#  ('res', 0, 12001): 'terms related to slowness or delay',
#  ('res', 0, 12002): 'instances of the word "guard."',
#  ('res', 0, 12003): 'references to garage doors',
#  ('res', 0, 12004): 'instances of the word "new"',
#  ('res',
#   0,
#   12005): 'references to laboratory environments and scientific equipment',
#  ('res',
#   0,
#   12006): ' mentions of "bay" and terms related to planning or vision',
#  ('res',
#   0,
#   12007): 'references to "cy" or related terms in scientific and technical contexts',
#  ('res', 0, 12008): 'references to filenames in the text',
#  ('res',
#   0,
#   12009): 'references to specific scientific terms or species names, particularly related to barley and its pathogens',
#  ('res',
#   0,
#   1201): ' occurrences of the term "bes" and its variations in the context of measurements or assessments',
#  ('res',
#   0,
#   12010): 'elements related to biological classifications and specific scientific terms or processes',
#  ('res', 0, 12011): 'references to biological tissues',
#  ('res',
#   0,
#   12012): ' references to relationships and linkages in data or concepts',
#  ('res', 0, 12013): 'references to fluid dynamics and flow processes',
#  ('res',
#   0,
#   12014): ' phrases or clauses that imply obligations or requirements',
#  ('res',
#   0,
#   12015): 'repeated mentions of the term "apache" and references to ellipses ("...")',
#  ('res', 0, 12016): 'references to spectral analysis and characteristics',
#  ('res', 0, 12017): 'references to complexity or intricate systems',
#  ('res', 0, 12018): ' terms related to chronic conditions and toxicity',
#  ('res',
#   0,
#   12019): 'terms related to biological differentiation and maturation processes in cells',
#  ('res', 0, 1202): 'references to caching mechanisms',
#  ('res', 0, 12020): 'mentions of the term "privilege" in various contexts',
#  ('res', 0, 12021): 'elements related to programming namespaces',
#  ('res',
#   0,
#   12022): "the concept or idea referencing a 'notion' across various contexts",
#  ('res', 0, 12023): ' programming-related commands and functions used in code',
#  ('res',
#   0,
#   12024): 'technical terminology and programming constructs related to data encoding and storage',
#  ('res', 0, 12025): 'words related to victories or wins in various contexts',
#  ('res', 0, 12026): ' references to monetary values',
#  ('res', 0, 12027): 'references to the concept of evolution',
#  ('res',
#   0,
#   12028): 'references to the term "Great," particularly in relation to historical or significant contexts',
#  ('res',
#   0,
#   12029): 'terms related to medical and biochemical contexts, particularly those involving disease and treatment references',
#  ('res', 0, 1203): ' occurrences of the word "direct" in various contexts',
#  ('res',
#   0,
#   12030): 'phrases related to the concept of increasing progression or change',
#  ('res', 0, 12031): ' the word "only" in various contexts',
#  ('res', 0, 12032): 'references to companies and organizational entities',
#  ('res',
#   0,
#   12033): 'terms related to electoral processes and drafts in various contexts',
#  ('res',
#   0,
#   12034): ' references to pairs and the concept of remaining or staying in a particular state',
#  ('res',
#   0,
#   12035): ' occurrences of the jQuery dollar sign symbol ($) indicating JavaScript code snippets',
#  ('res', 0, 12036): 'references to proteins',
#  ('res',
#   0,
#   12037): "references to the Greek letter 'gamma' in various mathematical contexts",
#  ('res', 0, 12038): 'references to nuclear energy and nuclear-related terms',
#  ('res', 0, 12039): 'phrases indicating causation or effects',
#  ('res', 0, 1204): 'references to military ranks or commands',
#  ('res',
#   0,
#   12040): 'terms related to methods and parameters in programming or technical contexts',
#  ('res', 0, 12041): 'instances of the word "send" and its variations',
#  ('res', 0, 12042): 'terms related to liquid substances and hydroxyl groups',
#  ('res', 0, 12043): "terms related to 'special' or 'specialized' contexts",
#  ('res',
#   0,
#   12044): ' references to data structures and algorithms related to queues',
#  ('res',
#   0,
#   12045): ' terms related to software or system installation processes',
#  ('res',
#   0,
#   12046): 'keywords and phrases related to measurement and quality control in technology and manufacturing contexts',
#  ('res',
#   0,
#   12047): 'alphanumeric codes or abbreviations related to organizations or classifications',
#  ('res', 0, 12048): 'references to approximate quantities or measures',
#  ('res',
#   0,
#   12049): 'terms related to compatibility across different contexts and subjects',
#  ('res',
#   0,
#   1205): 'references to a specific hormone related to biological processes',
#  ('res',
#   0,
#   12050): 'references to structural boundaries and the concept of text',
#  ('res', 0, 12051): 'references to partnerships or collaborations',
#  ('res',
#   0,
#   12052): ' references to specific functions or variables in programming, particularly related to date and time management',
#  ('res', 0, 12053): 'references to gauge theories in physics',
#  ('res', 0, 12054): 'references to plastic materials',
#  ('res',
#   0,
#   12055): 'references to radio frequency (RF) components and related technology',
#  ('res', 0, 12056): 'terms related to applicable laws and regulations',
#  ('res', 0, 12057): 'terms related to significant or notable characteristics',
#  ('res',
#   0,
#   12058): ' references to a specific protein or biological term indicated by "N9"',
#  ('res',
#   0,
#   12059): 'terms related to indications and estimates of conditions or situations',
#  ('res',
#   0,
#   1206): 'conditional statements or instructions in programming contexts',
#  ('res',
#   0,
#   12060): 'technical terms and data structures related to programming and prototyping',
#  ('res',
#   0,
#   12061): 'references to secondary elements or components in various contexts',
#  ('res',
#   0,
#   12062): ' references to model-related terminology in coding or framework contexts',
#  ('res',
#   0,
#   12063): 'technical terms and components related to software development and data analysis',
#  ('res',
#   0,
#   12064): 'technical terms related to programming and software development',
#  ('res',
#   0,
#   12065): ' references to specific individuals or entities, particularly in a context that indicates their significance or role',
#  ('res',
#   0,
#   12066): 'terms related to survival and cellular mechanisms in various biological contexts',
#  ('res', 0, 12067): " instances of the word 'smooth'",
#  ('res', 0, 12068): 'references to the color green',
#  ('res', 0, 12069): ' references to shiny or valuable objects',
#  ('res', 0, 1207): 'phrases indicating the highest quality or superiority',
#  ('res', 0, 12070): 'references to transparency in various contexts',
#  ('res',
#   0,
#   12071): 'terms related to specific medical conditions and pharmaceutical development',
#  ('res',
#   0,
#   12072): ' instances of the word "inline" in code contexts, particularly in a programming or technical document',
#  ('res', 0, 12073): 'references to RF (Radio Frequency)',
#  ('res', 0, 12074): ' package and import statements in programming code',
#  ('res', 0, 12075): ' references to the concept of honor',
#  ('res', 0, 12076): 'phrases that inquire about quantities or amounts',
#  ('res',
#   0,
#   12077): ' patterns associated with numerical data, particularly in formatted contexts like statistics or scientific notation',
#  ('res', 0, 12078): 'references to the name "Williams"',
#  ('res',
#   0,
#   12079): 'mentions of names, particularly "Kam" and related variations',
#  ('res', 0, 1208): 'terms related to collisions',
#  ('res',
#   0,
#   12080): 'technical terms and references related to programming and software development',
#  ('res',
#   0,
#   12081): 'references to data packets and associated passwords in context',
#  ('res', 0, 12082): 'references to specific legal or constitutional terms',
#  ('res', 0, 12083): 'terms related to religion and religious practices',
#  ('res', 0, 12084): 'references to danger or threats',
#  ('res',
#   0,
#   12085): ' conditions and constraints related to numerical thresholds in the code',
#  ('res', 0, 12086): 'terms and phrases related to definitions or descriptions',
#  ('res', 0, 12087): 'references to streets and related locations',
#  ('res', 0, 12088): ' occurrences of the word "blank"',
#  ('res', 0, 12089): 'the name or reference to a specific brand or company',
#  ('res', 0, 1209): 'instances of the word "restore" in various contexts',
#  ('res', 0, 12090): 'words that indicate inclusion or addition in statements',
#  ('res',
#   0,
#   12091): 'terms related to assemblies and programming structures in coding contexts',
#  ('res', 0, 12092): 'references to handling or management in various contexts',
#  ('res', 0, 12093): 'mentions of the word "breath"',
#  ('res',
#   0,
#   12094): 'the presence of terminology related to scientific and medical concepts',
#  ('res',
#   0,
#   12095): 'references to emperors and their roles in historical contexts',
#  ('res', 0, 12096): 'references to receipts',
#  ('res', 0, 12097): ' the phrase "is there."',
#  ('res', 0, 12098): ' references to attributes in XML or HTML contexts',
#  ('res', 0, 12099): ' references to mobile technology',
#  ('res', 0, 121): 'expressions of pride or prideful sentiments',
#  ('res',
#   0,
#   1210): ' terms related to authentication and authorization processes',
#  ('res', 0, 12100): 'references to the name "William"',
#  ('res',
#   0,
#   12101): 'terms associated with a specific organizational entity or its identification',
#  ('res',
#   0,
#   12102): 'abbreviations and acronyms, particularly those related to organizations, institutions, or technical terms.',
#  ('res',
#   0,
#   12103): 'technical terms and keywords related to programming, especially in Java and Android development',
#  ('res',
#   0,
#   12104): ' references to the concept of "pieces" in various contexts',
#  ('res', 0, 12105): 'references to academic theses and scholarly work',
#  ('res',
#   0,
#   12106): 'different punctuation marks and their occurrence within the text',
#  ('res', 0, 12107): 'references to German identity or association',
#  ('res',
#   0,
#   12108): ' symbols and terms related to addition or positive increments',
#  ('res', 0, 12109): 'unique terms and their associated values',
#  ('res',
#   0,
#   1211): ' occurrences of the word "promised" and its related forms, indicating expectations or commitments',
#  ('res', 0, 12110): 'terms related to reproduction and fertility',
#  ('res', 0, 12111): 'references to work and employment',
#  ('res', 0, 12112): 'terms related to research and academic studies',
#  ('res',
#   0,
#   12113): 'references to Java programming language components, especially those involving the `javax` package',
#  ('res',
#   0,
#   12114): 'tags and symbols used in markup languages or programming languages',
#  ('res',
#   0,
#   12115): 'references to pregnancy and related booking or scheduling activities',
#  ('res', 0, 12116): ' strings that denote documentation or comments in code',
#  ('res', 0, 12117): 'words related to familial relationships and genealogy',
#  ('res',
#   0,
#   12118): 'references to types of folding or processes that involve folding',
#  ('res', 0, 12119): 'pronouns related to possession and ownership',
#  ('res',
#   0,
#   1212): 'references to researchers and their activities in scientific contexts',
#  ('res',
#   0,
#   12120): 'phrases emphasizing the importance of remaining consistent or persevering',
#  ('res', 0, 12121): 'terms related to electric charge and its interactions',
#  ('res',
#   0,
#   12122): 'references to "Bay" and associated cultural aspects in the document',
#  ('res', 0, 12123): 'themes related to fear and anxiety',
#  ('res', 0, 12124): 'terms and concepts related to death and mortality',
#  ('res', 0, 12125): 'references to fees and associated financial terms',
#  ('res', 0, 12126): ' instances of the prefix "co-" used in various contexts',
#  ('res', 0, 12127): 'references to "plugs" and "plugging" in various contexts',
#  ('res', 0, 12128): 'words or phrases with variations of "que."',
#  ('res', 0, 12129): ' the term "available" in various contexts',
#  ('res', 0, 1213): 'the occurrences of the term "Ma" in various contexts',
#  ('res', 0, 12130): 'references to leaves in the text',
#  ('res',
#   0,
#   12131): 'references to the Ninth and Eighth Amendments of the U.S. Constitution',
#  ('res',
#   0,
#   12132): 'references to the characteristics of concepts or methods in a specific domain of knowledge',
#  ('res', 0, 12133): 'instances of the word "walk" and its variations',
#  ('res', 0, 12134): 'references to rhythm in various contexts',
#  ('res',
#   0,
#   12135): 'descriptions of spaces and their features, particularly in relation to real estate',
#  ('res', 0, 12136): ' instances of sarcasm or irony',
#  ('res', 0, 12137): 'terms related to documentation and copyright notices',
#  ('res', 0, 12138): 'terms related to sessions and molecular interactions',
#  ('res',
#   0,
#   12139): 'instances of the word "change" and its related forms or contexts',
#  ('res', 0, 1214): 'references to numerical quantities or measurements',
#  ('res', 0, 12140): 'references to justice and injustice',
#  ('res', 0, 12141): 'references to funding and grants',
#  ('res', 0, 12142): ' expressions of willingness or consent',
#  ('res',
#   0,
#   12143): 'references to the concept of "drafting" in various contexts',
#  ('res',
#   0,
#   12144): 'keywords and phrases related to detailed technical descriptions or specifications',
#  ('res', 0, 12145): ' words or phrases indicating ability or capability',
#  ('res', 0, 12146): ' expressions of necessity or requirements',
#  ('res',
#   0,
#   12147): ' occurrences of the word "administration" and related terms',
#  ('res',
#   0,
#   12148): 'terms related to detection methods, particularly in the context of viral nucleic acids',
#  ('res', 0, 12149): 'references to federal entities or legislation',
#  ('res', 0, 1215): 'proper nouns and specific individuals in texts',
#  ('res',
#   0,
#   12150): 'terms related to specific experimental techniques and observations in scientific research, particularly involving mice and pigs',
#  ('res',
#   0,
#   12151): ' instances of the word "ure" and related endings in a context relevant to locations or names',
#  ('res',
#   0,
#   12152): 'mathematical symbols and variables related to parameterized models',
#  ('res',
#   0,
#   12153): 'percentage or formatting placeholders within technical contexts, particularly in code or error messages',
#  ('res', 0, 12154): 'references to physical bodies and printing processes',
#  ('res',
#   0,
#   12155): 'instances of the term "kind" and related terms describing types or categories',
#  ('res', 0, 12156): ' references to data structures in programming',
#  ('res',
#   0,
#   12157): 'mentions of a specific point of origin, particularly in relation to people or things being discussed',
#  ('res', 0, 12158): 'terms related to cyber activities and security',
#  ('res',
#   0,
#   12159): 'numerical values, specifically those related to ratings, scores, or measurements',
#  ('res', 0, 1216): 'terms related to depth and intensity in various contexts',
#  ('res',
#   0,
#   12160): 'repeated use of the prefix "lo" and occurrences of the word "early"',
#  ('res',
#   0,
#   12161): 'terminology related to scientific processes and programming structures',
#  ('res',
#   0,
#   12162): ' names and terms related to software components or classes',
#  ('res', 0, 12163): 'terms related to rental agreements and leasing',
#  ('res', 0, 12164): 'import statements in Python',
#  ('res',
#   0,
#   12165): ' technical terms and concepts related to medical and causal inference',
#  ('res', 0, 12166): ' references to personal names and birthdates',
#  ('res',
#   0,
#   12167): ' references to educational institutions and related components',
#  ('res', 0, 12168): ' discussions or references to conversations',
#  ('res', 0, 12169): ' instances of copyright-related terminology',
#  ('res',
#   0,
#   1217): ' instances of specific formatting or symbols, such as decimal points and tags',
#  ('res',
#   0,
#   12170): 'references to anatomical or medical terminology related to the mesenteric area',
#  ('res', 0, 12171): 'references to websites and web-based content',
#  ('res', 0, 12172): 'references to dragons',
#  ('res', 0, 12173): 'references to measurement units related to distance',
#  ('res', 0, 12174): 'HTML and React component tags',
#  ('res',
#   0,
#   12175): 'the term "um" which likely indicates hesitation or uncertainty in discussions',
#  ('res', 0, 12176): 'phrases indicating verification or assurance',
#  ('res', 0, 12177): ' words indicating output or results in various contexts',
#  ('res',
#   0,
#   12178): 'references to user interface components, particularly view controllers in programming or software contexts',
#  ('res', 0, 12179): 'references to HIV and related terms',
#  ('res', 0, 1218): 'references to screws and their characteristics',
#  ('res',
#   0,
#   12180): 'repeated reminders or advice to remember something important',
#  ('res', 0, 12181): ' strings related to database query syntax',
#  ('res', 0, 12182): 'HTML header tags used in web development documentation',
#  ('res',
#   0,
#   12183): 'instances of the word "pause" and other related contextual indications of delay or interruption',
#  ('res',
#   0,
#   12184): ' terms related to modules and their organization in a coding context',
#  ('res',
#   0,
#   12185): ' instances of the word "correct" and related terms indicating accuracy or appropriateness',
#  ('res',
#   0,
#   12186): ' concepts related to inhibition and inhibitory effects in biological contexts',
#  ('res',
#   0,
#   12187): ' references to editing actions, particularly in a programming or software context',
#  ('res', 0, 12188): 'references to languages and bilingualism',
#  ('res',
#   0,
#   12189): 'terms and phrases that indicate error or fault in various contexts',
#  ('res',
#   0,
#   1219): ' references to text formatting identifiers or keywords related to bold text styling',
#  ('res',
#   0,
#   12190): 'legal terms and conditions related to warranties and liabilities',
#  ('res',
#   0,
#   12191): 'references to the name "Roy" in the context of achievements or accolades',
#  ('res', 0, 12192): 'terms related to urgency and rapid action',
#  ('res', 0, 12193): 'units of measurement, specifically related to volume',
#  ('res', 0, 12194): 'references to "cloning" and related terms',
#  ('res', 0, 12195): ' words related to trucks and their components',
#  ('res', 0, 12196): 'references to individuals classified as residents',
#  ('res', 0, 12197): ' instances of the word "communicate."',
#  ('res', 0, 12198): ' terms related to business ventures and partnerships',
#  ('res', 0, 12199): 'references to tiles and tile-related products',
#  ('res', 0, 122): 'references to various types of "baskets" and "chains"',
#  ('res',
#   0,
#   1220): 'references to shaking, both as a physical action and in various contexts',
#  ('res', 0, 12200): 'references to various sports or athletic activities',
#  ('res',
#   0,
#   12201): 'references to corporate entities or organizations, specifically those labeled as "Inc."',
#  ('res',
#   0,
#   12202): 'references to sandwiches, particularly the Reuben sandwich and related dishes',
#  ('res', 0, 12203): 'mathematical variables and symbols',
#  ('res',
#   0,
#   12204): ' terms that refer to "base" or "basal" in a biological or contextual sense',
#  ('res',
#   0,
#   12205): 'elements and attributes related to user interface components in programming code',
#  ('res',
#   0,
#   12206): ' references to loneliness and isolation in various contexts',
#  ('res', 0, 12207): 'the pronoun "I" in various contexts',
#  ('res',
#   0,
#   12208): 'mentions of specific biochemical terms related to cell metabolism',
#  ('res',
#   0,
#   12209): 'specific scientific terminologies and names related to cell biology and immunology',
#  ('res', 0, 1221): 'references to specific sites or locations',
#  ('res', 0, 12210): 'references to names',
#  ('res', 0, 12211): 'the name "Walker" in various contexts',
#  ('res', 0, 12212): ' terms related to rankings and adjustments',
#  ('res',
#   0,
#   12213): 'references to segments or portions in a document, particularly in a technical context',
#  ('res', 0, 12214): ' instances of the word "change" and its variations',
#  ('res',
#   0,
#   12215): 'technical terms and components related to programming and encryption',
#  ('res', 0, 12216): 'expressions of concern or worry',
#  ('res', 0, 12217): 'references to education and educational concepts',
#  ('res', 0, 12218): ' references to radio frequency (RF) technology',
#  ('res',
#   0,
#   12219): ' the term "rid" and various forms of code export statements',
#  ('res',
#   0,
#   1222): 'instances of the word "introduce" and phrases related to timing or preconditions',
#  ('res',
#   0,
#   12220): 'references to "mother" and related family terms in the text',
#  ('res',
#   0,
#   12221): 'scientific terms related to cellular biology and genetics',
#  ('res',
#   0,
#   12222): 'terms related to responses and selective processes in biological contexts',
#  ('res',
#   0,
#   12223): ' ordinal indicators and terms related to ranking or positioning',
#  ('res', 0, 12224): 'expressions of desire or longing for something',
#  ('res', 0, 12225): 'terminology and concepts related to photography',
#  ('res',
#   0,
#   12226): 'references to the term "la" and related entities, often signifying a particular theme or context',
#  ('res',
#   0,
#   12227): 'technical terms and references related to programming and data structures',
#  ('res',
#   0,
#   12228): 'words and phrases indicating time progression or sequence',
#  ('res', 0, 12229): 'references to "circumstances."',
#  ('res',
#   0,
#   1223): 'technical terms and references related to programming and web development',
#  ('res', 0, 12230): 'words related to butter',
#  ('res', 0, 12231): ' references to user-related entities or objects',
#  ('res',
#   0,
#   12232): 'instances of the term "result" and its variations in various contexts',
#  ('res',
#   0,
#   12233): " words that indicate processes or actions, particularly those ending with 'ation'",
#  ('res', 0, 12234): 'references to periods and time intervals',
#  ('res',
#   0,
#   12235): 'keywords related to motion or direction, particularly the word "headed" and related terms',
#  ('res', 0, 12236): 'references to racism and slavery',
#  ('res',
#   0,
#   12237): 'URLs and file path components related to data extraction and programming functions',
#  ('res',
#   0,
#   12238): ' instances of the word "super" and occurrences of the keyword "IN"',
#  ('res',
#   0,
#   12239): 'mentions of political titles, specifically related to governors',
#  ('res',
#   0,
#   1224): 'terms related to hydro dynamics and associated parameters in scientific contexts',
#  ('res',
#   0,
#   12240): ' terms related to forms and structures in a scientific or engineering context',
#  ('res',
#   0,
#   12241): ' references to modernity or contemporary aspects in various contexts',
#  ('res',
#   0,
#   12242): 'references to "incidence" or "increased incidence" in medical or treatment contexts',
#  ('res', 0, 12243): 'terms associated with refusal or denial',
#  ('res',
#   0,
#   12244): 'terms related to the concepts of removal or residuals in processes',
#  ('res',
#   0,
#   12245): 'mentions of specific compounds or substances, particularly in a medical or toxicological context',
#  ('res',
#   0,
#   12246): 'the occurrence of the name "Yo" or its variations in different contexts',
#  ('res', 0, 12247): 'instances of the word "despite."',
#  ('res',
#   0,
#   12248): 'functions and variables related to state management and condition checking',
#  ('res',
#   0,
#   12249): 'specific technical terms and code structures related to programming and software development',
#  ('res', 0, 1225): 'conjunctions and their frequency in multiple contexts',
#  ('res',
#   0,
#   12250): 'references to specific legal sections or provisions in texts',
#  ('res',
#   0,
#   12251): 'prepositions and associated phrases indicating direction or purpose',
#  ('res',
#   0,
#   12252): 'references to technical terms and concepts related to programming and software development',
#  ('res', 0, 12253): 'references to index-related terms or identifiers',
#  ('res', 0, 12254): 'references to specific scientific concepts and terms',
#  ('res', 0, 12255): 'terms related to authentication processes',
#  ('res', 0, 12256): 'references to diabetes and related conditions',
#  ('res', 0, 12257): ' instances of the word "confirmed."',
#  ('res', 0, 12258): 'references to gate electrodes in a semiconductor context',
#  ('res', 0, 12259): 'terms related to financial transactions and greetings',
#  ('res', 0, 1226): 'HTML or XML tag structures and their attributes',
#  ('res',
#   0,
#   12260): 'programming constructs related to session management and operations involving parent nodes in a tree structure',
#  ('res',
#   0,
#   12261): 'references to individuals and organizations involved in political or bureaucratic contexts',
#  ('res',
#   0,
#   12262): 'references to specific scientific entities and processes related to chemistry and microbiology',
#  ('res', 0, 12263): 'units of measurement related to weight and volume',
#  ('res', 0, 12264): 'references to the name "Chen."',
#  ('res', 0, 12265): 'references to integrated circuits (ICs)',
#  ('res', 0, 12266): 'references to "ice."',
#  ('res', 0, 12267): 'punctuation marks or symbols',
#  ('res',
#   0,
#   12268): 'expressions related to variability or change in measurements or observations',
#  ('res',
#   0,
#   12269): ' references to "windows" or window-related contexts in technical or narrative descriptions',
#  ('res', 0, 1227): ' lists or sequences of items',
#  ('res', 0, 12270): 'complex systems and technical references',
#  ('res',
#   0,
#   12271): ' numerical references or indicators in a structured context',
#  ('res',
#   0,
#   12272): 'references to mathematical orders or order-of-magnitude concepts in the context of models or estimators',
#  ('res', 0, 12273): 'expressions of fear and anxiety',
#  ('res',
#   0,
#   12274): 'specific names and locations, particularly in a scientific context',
#  ('res',
#   0,
#   12275): ' terms related to military weapons and their specifications',
#  ('res', 0, 12276): 'references to harm or damage',
#  ('res', 0, 12277): 'terms related to reliance or dependence on something',
#  ('res',
#   0,
#   12278): 'references to destinations and the concept of targeting within various contexts',
#  ('res',
#   0,
#   12279): ' occurrences and mentions of roles and joint responsibilities',
#  ('res',
#   0,
#   1228): ' programming terminology and functions related to data handling',
#  ('res', 0, 12280): ' terms related to programming structures and functions',
#  ('res',
#   0,
#   12281): 'negations or expressions of what is not true or acceptable',
#  ('res', 0, 12282): ' references to time or temporal context',
#  ('res',
#   0,
#   12283): 'terms related to dependence and stability in various contexts',
#  ('res',
#   0,
#   12284): ' recommendations or suggestions in relation to various topics',
#  ('res',
#   0,
#   12285): 'references to mutations and related terms in biological contexts',
#  ('res',
#   0,
#   12286): ' references to slope or gradient measurements in data or analysis contexts',
#  ('res',
#   0,
#   12287): 'legal terminology associated with favorable court rulings',
#  ('res', 0, 12288): ' mathematical symbols and relational operators',
#  ('res',
#   0,
#   12289): 'terms related to contributions and their significance in various contexts',
#  ('res', 0, 1229): ' references to "clock" and related timing concepts',
#  ('res', 0, 12290): 'expressions of luck or fortunate circumstances',
#  ('res',
#   0,
#   12291): 'numerical data, particularly related to measurements or specifications',
#  ('res', 0, 12292): 'co-variants in mathematical or scientific contexts',
#  ('res',
#   0,
#   12293): 'the term "discharge" in various contexts, indicating a focus on the concept of release or ejection, often in medical or electrical settings',
#  ('res',
#   0,
#   12294): 'terms and phrases related to tightness and secure fits in various contexts',
#  ('res', 0, 12295): 'references to hunting and related activities',
#  ('res',
#   0,
#   12296): ' static keywords and recurring terms in code or technical text',
#  ('res',
#   0,
#   12297): ' concepts related to compliance and adherence in various contexts',
#  ('res', 0, 12298): 'references to rubber materials in various contexts',
#  ('res', 0, 12299): 'terms associated with size and significance',
#  ('res',
#   0,
#   123): ' references to chaotic or tumultuous situations and relationships',
#  ('res', 0, 1230): 'terms related to speed in various contexts',
#  ('res', 0, 12300): 'instances of the word "adapt" and its variations',
#  ('res', 0, 12301): ' instances of the word "router"',
#  ('res', 0, 12302): 'terms related to athletes and workouts',
#  ('res', 0, 12303): ' references to the element "el" in various contexts',
#  ('res',
#   0,
#   12304): 'mentions of government ministries, specifically the Ministry of Health and its related contexts',
#  ('res', 0, 12305): ' references to specific types of visual media or images',
#  ('res',
#   0,
#   12306): 'references related to computational processes or programming terminology',
#  ('res',
#   0,
#   12307): 'references to prestigious educational institutions, particularly Harvard and MIT',
#  ('res', 0, 12308): 'references to the concept of truth and its significance',
#  ('res', 0, 12309): 'terms related to appearance and design',
#  ('res', 0, 1231): 'assertions related to factual claims',
#  ('res',
#   0,
#   12310): 'instances of the word "register" and its variations in different contexts',
#  ('res', 0, 12311): 'references to soil',
#  ('res',
#   0,
#   12312): 'references to purchasing and costs associated with buying items',
#  ('res', 0, 12313): 'references to dedication in various contexts',
#  ('res',
#   0,
#   12314): 'references to application-related terminology and the concept of trust',
#  ('res',
#   0,
#   12315): 'technical terms related to quantum physics and programming concepts',
#  ('res', 0, 12316): 'references to "center" in various contexts',
#  ('res', 0, 12317): ' references to systematic processes or methodologies',
#  ('res',
#   0,
#   12318): 'references to specific measurement units or terms related to units of measurement',
#  ('res', 0, 12319): 'references to sodium (Na) in various contexts',
#  ('res', 0, 1232): ' Java import statements and class definitions',
#  ('res', 0, 12320): 'words related to expectation and anticipation',
#  ('res',
#   0,
#   12321): 'phrases or instructions involving "how to" followed by actions or tasks',
#  ('res',
#   0,
#   12322): ' references to military operations and operations in general',
#  ('res', 0, 12323): 'comments or documentation headers in code',
#  ('res', 0, 12324): 'instances of the word "explain"',
#  ('res', 0, 12325): ' occurrences of the word "flip."',
#  ('res', 0, 12326): ' references to responses in a programming or API context',
#  ('res',
#   0,
#   12327): ' references to financial costs or expenses, particularly in a public or administrative context',
#  ('res', 0, 12328): 'terms related to economic impact or considerations',
#  ('res', 0, 12329): 'the prefix "pre" in various contexts',
#  ('res', 0, 1233): 'the word "even" used in various contexts',
#  ('res',
#   0,
#   12330): 'quantitative data and numerical values related to findings or measurements',
#  ('res', 0, 12331): 'content related to HTML table structure and formatting',
#  ('res', 0, 12332): 'instances of the word "no" or "not" indicating negation',
#  ('res',
#   0,
#   12333): 'technical terms and annotations related to programming or mathematical constructs in a structured format',
#  ('res',
#   0,
#   12334): 'instances of the word "reveal" and its variations in different contexts',
#  ('res', 0, 12335): ' mentions of royalty and royal structures',
#  ('res', 0, 12336): ' references to magazines or related publications',
#  ('res', 0, 12337): ' terms related to regional significance or areas',
#  ('res', 0, 12338): ' occurrences of the word "in" and its variations',
#  ('res', 0, 12339): ' references to error messages within a technical context',
#  ('res', 0, 1234): 'references to extreme conditions or situations',
#  ('res', 0, 12340): 'instances of the word "opposite."',
#  ('res',
#   0,
#   12341): 'references to medical conditions or diagnostic assessments',
#  ('res', 0, 12342): 'references to the name "Hal" in various contexts',
#  ('res', 0, 12343): 'phrases expressing persistence or continuity over time',
#  ('res', 0, 12344): 'mentions of specific food items, particularly salads',
#  ('res',
#   0,
#   12345): 'references to different types of rooms in a house, particularly bathrooms and kitchens',
#  ('res', 0, 12346): 'instances of the word "repeat" and its variations',
#  ('res', 0, 12347): 'expressions or concepts related to infinity',
#  ('res',
#   0,
#   12348): ' mentions of the word "regular" or its variations, indicating typicality or frequency of occurrence',
#  ('res',
#   0,
#   12349): 'terms related to biochemistry, specifically those involving amino acids and protein kinases',
#  ('res', 0, 1235): 'syntax related to programming or code structure',
#  ('res',
#   0,
# ...
#  ('res',
#   0,
#   12561): ' instances of the word "transferred" and related actions within various contexts',
#  ('res', 0, 12562): 'references to academic journals',
#  ('res', 0, 12563): 'references to photography and photographers',
#  ('res', 0, 12564): 'instances of the word "silent" and its variations',
#  ('res',
#   0,
#   12565): 'references to physical locations or settings, particularly in legal or formal contexts',
#  ('res',
#   0,
#   12566): 'instances of the word "belong" indicating association or affiliation with various categories or groups',
#  ('res', 0, 12567): 'terms related to graduation and academic achievements',
#  ('res', 0, 12568): ' vocabulary related to sound and warfare',
#  ('res', 0, 12569): 'terms related to pointers in programming',
#  ('res', 0, 1257): 'references to breaks and breakdowns in various contexts',
#  ('res',
#   0,
#   12570): 'references to medical societies and organizations related to health and disease',
#  ('res',
#   0,
#   12571): ' terms related to interviews and utilization in various contexts',
#  ('res',
#   0,
#   12572): ' references to political terminology, specifically related to liberalism and routing',
#  ('res',
#   0,
#   12573): 'references to concepts that invoke a sense of moral judgment or conscience',
#  ('res', 0, 12574): 'the word "fore" and its variations',
#  ('res',
#   0,
#   12575): ' references to programming structures or components related to "pod" or similar constructs',
#  ('res',
#   0,
#   12576): 'terms related to medical conditions and programming constructs',
#  ('res',
#   0,
#   12577): ' terms related to "NO" status or conditions, indicating a negative or disallowed state',
#  ('res',
#   0,
#   12578): 'references to the concept of recognition or acknowledgment',
#  ('res', 0, 12579): 'terms related to machine learning',
#  ('res', 0, 1258): 'references to triangles and triangular shapes',
#  ('res', 0, 12580): ' references to widgets in a programming context',
#  ('res', 0, 12581): 'instances of the word "still."',
#  ('res',
#   0,
#   12582): ' the word "bit" and related phrases indicating small quantities or degrees',
#  ('res', 0, 12583): 'terms related to substances and incentives',
#  ('res', 0, 12584): 'references to file operations or openings',
#  ('res',
#   0,
#   12585): 'references to temperature, particularly indicating something is hot',
#  ('res',
#   0,
#   12586): 'terms related to JSON serialization and data structure annotations',
#  ('res',
#   0,
#   12587): 'references to familial relationships, particularly related to brothers',
#  ('res',
#   0,
#   12588): 'terms related to genetic factors and pathways in research contexts',
#  ('res',
#   0,
#   12589): 'HTML heading tags and their structure within the document',
#  ('res', 0, 1259): ' instances of the word "taken."',
#  ('res', 0, 12590): ' references to a specific character named "Gar."',
#  ('res', 0, 12591): 'terms related to convenience and ease of access',
#  ('res',
#   0,
#   12592): 'references to mouse-related actions and control commands in programming contexts',
#  ('res', 0, 12593): 'references to database cursors and font mentions',
#  ('res', 0, 12594): 'references to real-time events or processes',
#  ('res', 0, 12595): 'references to classrooms and classroom-related contexts',
#  ('res', 0, 12596): 'instances of the word "any"',
#  ('res', 0, 12597): 'references to mental health disorders',
#  ('res',
#   0,
#   12598): 'content related to spirituality and spiritual experiences',
#  ('res', 0, 12599): ' mentions of a specific error or exception type',
#  ('res', 0, 126): 'references to neglect in various contexts',
#  ('res',
#   0,
#   1260): ' LaTeX commands and structure used in mathematical documents',
#  ('res', 0, 12600): ' concepts related to barriers and the act of digging',
#  ('res', 0, 12601): 'references to the "Star Wars" franchise',
#  ('res',
#   0,
#   12602): 'words associated with food and taste, particularly those expressing deliciousness',
#  ('res',
#   0,
#   12603): 'mentions of "pure" in the context of materials or samples',
#  ('res',
#   0,
#   12604): 'phrases related to "border" and "port" attributes in a layout or interface context',
#  ('res',
#   0,
#   12605): 'instances of the word "join" and related terms indicating collaboration or partnership',
#  ('res', 0, 12606): 'mathematical symbols and notations',
#  ('res', 0, 12607): 'instances of the term "profile" across various contexts',
#  ('res',
#   0,
#   12608): 'references to CT imaging and its application in clinical contexts',
#  ('res',
#   0,
#   12609): ' references to technical specifications and programming elements related to software or application structure',
#  ('res',
#   0,
#   1261): ' references to timeframes and temporal contexts in discussions',
#  ('res', 0, 12610): 'references to the word "apple" in various forms',
#  ('res',
#   0,
#   12611): ' references to the concept of individual rights and personal identity',
#  ('res', 0, 12612): 'specific mentions of batteries and clusters',
#  ('res', 0, 12613): 'references to Sri Lanka and its administrative context',
#  ('res', 0, 12614): 'instances of the term "Ser" or related variations',
#  ('res',
#   0,
#   12615): 'references to financial spending and input data in various contexts',
#  ('res', 0, 12616): 'terms related to updates and version changes',
#  ('res', 0, 12617): 'terms related to errors and error handling',
#  ('res', 0, 12618): 'instances of the word "blog"',
#  ('res', 0, 12619): ' occurrences of the word "all"',
#  ('res',
#   0,
#   1262): 'words related to distinguishing or differentiating entities or characteristics',
#  ('res', 0, 12620): 'the verb "is" in various contexts',
#  ('res', 0, 12621): 'references to health and healthcare concepts',
#  ('res', 0, 12622): 'references to the younger demographic',
#  ('res',
#   0,
#   12623): 'references to specific individuals and entities, particularly related to categories and entities in sports and politics',
#  ('res',
#   0,
#   12624): 'references to independent entities or individuals, particularly in political or organizational contexts',
#  ('res',
#   0,
#   12625): 'terms related to water systems, specifically focusing on water quality, levels, and related engineering processes',
#  ('res', 0, 12626): 'references to variable names in a programming context',
#  ('res',
#   0,
#   12627): 'technical terms and specific identifiers related to various scientific or technical fields',
#  ('res', 0, 12628): 'terms related to motion and physical movement',
#  ('res', 0, 12629): 'mentions and references to bacteria in various contexts',
#  ('res',
#   0,
#   1263): ' references to Omega symbols, likely indicating a focus on scientific notation or parameters',
#  ('res', 0, 12630): 'references to the name "Ben."',
#  ('res', 0, 12631): ' instances of the word "realized" and its various forms',
#  ('res', 0, 12632): 'terms related to specialists or expertise',
#  ('res', 0, 12633): ' integer data types and their associated identifiers',
#  ('res', 0, 12634): " instances of the letter 'a'",
#  ('res',
#   0,
#   12635): 'specific names, brands, and terminology related to technology and programming',
#  ('res', 0, 12636): 'instances of the word "identify" and its variations',
#  ('res', 0, 12637): 'terms related to derivation and genetic concepts',
#  ('res', 0, 12638): 'references to the word "Spirit" in various contexts',
#  ('res', 0, 12639): 'terms related to authentication processes in systems',
#  ('res',
#   0,
#   1264): 'terms related to chemical compositions and processes, particularly involving biochemistry and cellular mechanisms',
#  ('res',
#   0,
#   12640): ' references to various substances or conditions related to health or medical efficacy',
#  ('res',
#   0,
#   12641): 'references to personal relationships and familial connections',
#  ('res',
#   0,
#   12642): 'references to journalists and their roles in various contexts',
#  ('res',
#   0,
#   12643): 'instances of expressions indicating lack of experience or familiarity',
#  ('res',
#   0,
#   12644): 'notations or representations related to data structures or programming constructs',
#  ('res', 0, 12645): 'references to sports teams and their group dynamics',
#  ('res',
#   0,
#   12646): ' jQuery selectors or commands used in JavaScript code snippets',
#  ('res', 0, 12647): ' JSON objects and their structures',
#  ('res',
#   0,
#   12648): 'mentions of professors and individuals associated with academic contexts',
#  ('res', 0, 12649): 'terms related to permissions and subscriptions',
#  ('res', 0, 1265): 'references to "typical" examples or characteristics',
#  ('res',
#   0,
#   12650): 'terms related to artistic tools and their application in the creative process',
#  ('res', 0, 12651): 'terms related to heat and thermal energy',
#  ('res', 0, 12652): ' references to centimeters',
#  ('res', 0, 12653): ' HTML header tags, particularly `<h2>` and `<h3>`',
#  ('res',
#   0,
#   12654): ' terms related to the distribution of resources or assignments',
#  ('res', 0, 12655): 'mentions of a specific name or term, particularly "Ken."',
#  ('res',
#   0,
#   12656): 'terms related to asynchronous programming and threading in code',
#  ('res', 0, 12657): 'terms related to financial matters',
#  ('res', 0, 12658): 'references to training or educational development',
#  ('res', 0, 12659): 'references to coaches and coaching-related terms',
#  ('res', 0, 1266): 'terms related to concentrations in scientific contexts',
#  ('res',
#   0,
#   12660): ' references to products or commodities in various contexts',
#  ('res',
#   0,
#   12661): ' references to actions within a coding or technology context',
#  ('res',
#   0,
#   12662): 'the term "anchor" and its variations in different contexts',
#  ('res', 0, 12663): ' mentions of fashion and related terms',
#  ('res', 0, 12664): 'references to donating and donations',
#  ('res', 0, 12665): 'pronouns relating to subjects and possessive references',
#  ('res', 0, 12666): 'terms related to clinical practices and evaluations',
#  ('res',
#   0,
#   12667): ' phrases related to clarification or description of topics',
#  ('res', 0, 12668): 'terminology related to sentencing in legal contexts',
#  ('res', 0, 12669): 'references to the concept of retirement',
#  ('res', 0, 1267): 'the name "Ben."',
#  ('res', 0, 12670): ' occurrences of the word "grab" in various contexts',
#  ('res', 0, 12671): 'instances of the word "coat" in various contexts',
#  ('res', 0, 12672): 'references to medication dosages',
#  ('res',
#   0,
#   12673): ' references to superclass methods and functions in programming contexts',
#  ('res', 0, 12674): 'terms related to the concept of politics',
#  ('res',
#   0,
#   12675): 'terms associated with clinical implications and outcomes related to drugs and toxicity in medical contexts',
#  ('res',
#   0,
#   12676): ' instances of HTML list item elements and their attributes',
#  ('res',
#   0,
#   12677): 'references to punishment and its various forms or implications',
#  ('res',
#   0,
#   12678): 'the word "the" in various contexts throughout the document',
#  ('res',
#   0,
#   12679): 'code annotations or metadata tags often used in programming contexts',
#  ('res',
#   0,
#   1268): 'terms related to development and evaluation in a scientific or technical context',
#  ('res',
#   0,
#   12680): 'references to specific conditions in a formal or academic context',
#  ('res', 0, 12681): 'references to testing frameworks and configurations',
#  ('res', 0, 12682): ' the presence of quotation marks',
#  ('res', 0, 12683): ' instances of the word "kiss" or related forms',
#  ('res', 0, 12684): 'references to tricks or deceptive strategies',
#  ('res', 0, 12685): 'technical programming terms and keywords',
#  ('res', 0, 12686): 'references to the palm of the hand',
#  ('res',
#   0,
#   12687): 'terms related to spatial and temporal variations in biological data',
#  ('res', 0, 12688): 'expressions of joy and positivity',
#  ('res', 0, 12689): 'references to gyms and fitness-related terms',
#  ('res', 0, 1269): 'references to drivers in various contexts',
#  ('res', 0, 12690): 'instances of first-person pronouns and contractions',
#  ('res', 0, 12691): 'references to chocolate or related terms',
#  ('res',
#   0,
#   12692): 'phrases indicating progress or distance in terms of evaluation or performance',
#  ('res',
#   0,
#   12693): ' instances of the word "chase" and related terms in various contexts',
#  ('res', 0, 12694): 'instances of the concept of hiding or concealment',
#  ('res', 0, 12695): 'phrases related to regulations or policies in place',
#  ('res',
#   0,
#   12696): ' instances of the word "Authority" and related terms in various contexts',
#  ('res', 0, 12697): 'phrases indicating composition or components',
#  ('res',
#   0,
#   12698): 'references to various challenges or difficulties in different contexts',
#  ('res', 0, 12699): 'terms related to the concept of "fluid."',
#  ('res', 0, 127): "instances of the word 'defeat' and related concepts",
#  ('res', 0, 1270): 'documents that contain descriptions or definitions',
#  ('res',
#   0,
#   12700): 'terms related to overflow issues and their occurrences in various contexts',
#  ('res', 0, 12701): 'instances of creativity in various contexts',
#  ('res',
#   0,
#   12702): 'instances of the word "miss" and its variations, indicating a focus on themes of absence or missed opportunities',
#  ('res', 0, 12703): 'references to success and achievement',
#  ('res', 0, 12704): 'references to specific geographic locations or wards',
#  ('res', 0, 12705): 'terms related to legal denials and appeals',
#  ('res',
#   0,
#   12706): 'references to parallel processing and its related concepts',
#  ('res', 0, 12707): 'references to function arguments in programming contexts',
#  ('res',
#   0,
#   12708): 'measurements and specifications related to dimensions in centimeters and millimeters',
#  ('res', 0, 12709): 'references to statistical measures and data analysis',
#  ('res',
#   0,
#   1271): ' instances of the word "succeed" and related concepts of success',
#  ('res', 0, 12710): 'instances of the word "used" and its variations',
#  ('res', 0, 12711): 'document titles and related terms',
#  ('res', 0, 12712): 'references to different species',
#  ('res',
#   0,
#   12713): 'references to the concept of "vision" in various contexts',
#  ('res', 0, 12714): ' occurrences of the term "chain" in various contexts',
#  ('res', 0, 12715): 'terms related to evaluation or assessment',
#  ('res', 0, 12716): ' occurrences of the substring "ph" in various contexts',
#  ('res',
#   0,
#   12717): 'references to judicial roles and positions, particularly related to "Justice."',
#  ('res',
#   0,
#   12718): 'references to geographic locations or zones, specifically those related to valleys and highlands',
#  ('res', 0, 12719): 'multiple instances of the word "as" in varying contexts',
#  ('res',
#   0,
#   1272): 'references to quality or classification grades of materials or products',
#  ('res',
#   0,
#   12720): ' mentions of "spare" and references to figures or diagrams',
#  ('res',
#   0,
#   12721): 'terms related to technical specifications or references in programming and technology',
#  ('res',
#   0,
#   12722): 'keywords related to accuracy and precision in measurements',
#  ('res', 0, 12723): 'phrases indicating existence or presence',
#  ('res',
#   0,
#   12724): 'terms associated with investments and financial transactions',
#  ('res', 0, 12725): 'words that indicate potential or likelihood',
#  ('res', 0, 12726): 'expressions of love and affection',
#  ('res', 0, 12727): 'mentions of the name "Richard."',
#  ('res', 0, 12728): 'elements related to data structures and their properties',
#  ('res', 0, 12729): 'terms related to distributed systems and data structures',
#  ('res', 0, 1273): 'instances of the word "qualify" and its variations',
#  ('res', 0, 12730): 'concepts related to evolution',
#  ('res', 0, 12731): 'terms related to ideologies and belief systems',
#  ('res',
#   0,
#   12732): 'references to the front of something, such as a location or object',
#  ('res', 0, 12733): 'solutions related to problem-solving in various contexts',
#  ('res',
#   0,
#   12734): ' gerunds or present participles, particularly those ending in "ering"',
#  ('res', 0, 12735): 'ways to indicate copyright and reservation of rights',
#  ('res', 0, 12736): 'references to triangular shapes and related terminology',
#  ...}

# %%
import pandas as pd

name = "math"
PATH = f"./datasets/dot_product/Judge/{name}_with_explanations.csv"
df = pd.read_csv(PATH)   # path to your empathetic file

df['Explanations'] = df.apply(
    lambda row: mapping.get((row['type'], row['layer'], row['Neuron_ID'])),
    axis=1
)

df.to_csv(PATH, index=False)
print(df.head())
# Out:
#   type  layer       class1      class2  Neuron_ID  Contribution  \
# 0  mlp      7  precalculus    geometry       6117  4.830805e+09
# 1  mlp     24  precalculus    geometry       9329  4.825307e+09
# 2  mlp     23  precalculus    geometry      10184  4.382280e+09
# 3  res      1  precalculus    geometry      12054  3.802484e+09
# 4  att      4     geometry  prealgebra       4742  3.458361e+09
#
#                                         Explanations
# 0   topics related to nutrition and health measur...
# 1   legal terms and phrases related to court case...
# 2  mathematical or analytical expressions related...
# 3  content related to medical conditions and trea...
# 4   attends to specific keywords marked with doub...
